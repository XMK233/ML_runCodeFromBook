# %%
import random, os, tqdm, time, json, re
import numpy as np
import pandas as pd
from matplotlib.font_manager import FontProperties
import matplotlib.pyplot as plt
from datetime import datetime

import sys
sys.path.append("../../../")

random.seed(618)
np.random.seed(907)

new_base_path = os.path.join(
    "/Users/minkexiu/Downloads/",
    "/".join(
        os.getcwd().split("/")[-1*(len(sys.path[-1].split("/")) - 1):]
    ),
)
print("storage dir:", new_base_path)
print("code dir:", os.getcwd())

## 创建文件夹。
if not os.path.exists(new_base_path):
    os.makedirs(
        new_base_path
    )
if not os.path.exists(os.path.join(new_base_path, "preprocessedData")):
    os.makedirs(
        os.path.join(new_base_path, "preprocessedData")
    )
if not os.path.exists(os.path.join(new_base_path, "originalData")):
    os.makedirs(
        os.path.join(new_base_path, "originalData")
    )
if not os.path.exists(os.path.join(new_base_path, "trained_models")):
    os.makedirs(
        os.path.join(new_base_path, "trained_models")
    )

def create_originalData_path(filename_or_path):
    return os.path.join(new_base_path, "originalData", filename_or_path)
def create_preprocessedData_path(filename_or_path):
    return os.path.join(new_base_path, "preprocessedData", filename_or_path)
def create_trained_models_path(filename_or_path):
    return os.path.join(new_base_path, "trained_models", filename_or_path)

def millisec2datetime(timestamp):
    time_local = time.localtime(timestamp/1000)
    return time.strftime("%Y-%m-%d %H:%M:%S", time_local)
    
def run_finish():
    # 假设你的字体文件是 'myfont.ttf' 并且位于当前目录下  
    font = FontProperties(fname="/Users/minkexiu/Documents/GitHub/ML_Tryout/SimHei.ttf", size=24)  
    # 创建一个空白的图形  
    fig, ax = plt.subplots()  
    ax.imshow(
        plt.imread("/Users/minkexiu/Downloads/wallhaven-dgxpyg.jpg")
    )
    # 在图形中添加文字  
    ax.text(
        ax.get_xlim()[1] * 0.5, 
        ax.get_ylim()[0] * 0.5, 
        f"程序于这个点跑完：\n{millisec2datetime(time.time()*1000)}", fontproperties=font, ha="center", va="center", color="red"
    )  
    # 设置图形的布局  
    # ax.set_xlim(0, 1)  
    # ax.set_ylim(0, 1)  
    ax.set_xticks([])  
    ax.set_yticks([])  
    ax.patch.set_color("blue")
    # 显示图形  
    plt.show()
        
tqdm.tqdm.pandas() ## 引入这个，就可以在apply的时候用progress_apply了。

import IPython
def kill_current_kernel():
    '''杀死当前的kernel释放内存空间。'''
    IPython.Application.instance().kernel.do_shutdown(True) 
    
def simply_show_data(df1):
    print(df1.shape)
    display(df1.head())
    
def wait_flag(saved_flag_path, time_interval_sec=10):
    print("waiting for", saved_flag_path)
    time_count = 0
    while True:
        if os.path.exists(saved_flag_path):
            break
        time.sleep(time_interval_sec)
        time_count+=time_interval_sec
        print(time_count, end=" ")
    print("finish!!")

def parallelly_run_multiple_similar_python_code(codes, nb_workers = 4):
    '''
    codes是多条相似的python代码。
    这个函数的作用就是将其平行地跑，每一条python代码就对应一个线程。或许可以后续优化，比如固定线程数为一个特定值。
    nb_workers 如果赋值为
    '''
    assert (isinstance(nb_workers, int)), "`nb_workers' should be int."
    df_sqls = pd.DataFrame(
        {
            "func": codes

        }
    )
    display(df_sqls)
    from pandarallel import pandarallel
    pandarallel.initialize(nb_workers = df_sqls.shape[0] if nb_workers<0 else nb_workers, progress_bar = True)
    def run_sql_prlly(row):
        try: 
            cmd = f'{row["func"]}'
            print(cmd, "\n")
            eval(cmd)
            return "0-success"
        except Exception as e:
            return e
    df_sqls["run_rsts"] = df_sqls.parallel_apply(lambda row: run_sql_prlly(row), axis = 1)
    display(df_sqls)
    
def create_originalData_path(filename_or_path):
    return os.path.join(new_base_path, "originalData", filename_or_path)
def create_preprocessedData_path(filename_or_path):
    return os.path.join(new_base_path, "preprocessedData", filename_or_path)
def create_trained_models_path(filename_or_path):
    return os.path.join(new_base_path, "trained_models", filename_or_path)
    
class TimerContext:  
    def __enter__(self):  
        self.start_time = str(datetime.now())
        print("start time:", self.start_time)
        return self  
    def __exit__(self, exc_type, exc_val, exc_tb):  
        print("start time:", self.start_time)
        print("end time", str(datetime.now()))

def three_num_get_gua(a, b, c):
    '''梅花易数三数起卦，以取本、互、变。'''
    bagua = ["111", "110", "101", "100", "011", "010", "001", "000"]
    guatu = {
        "111": ("☰", "天", "乾金"), 
        "110": ("☱", "泽", "兑金"),
        "101": ("☲", "火", "离火"),
        "100": ("☳" , "雷", "震木"),
        "011": ("☴", "风", "巽木"),
        "010": ("☵", "水", "坎水"),
        "001": ("☶", "山", "艮土"),
        "000": ("☷", "地", "坤土"),
    }
    shanggua_idx = 7 if (a % 8 == 0) else (a % 8 - 1)
    xiagua_idx = 7 if (b % 8 == 0) else (b % 8 - 1)
    bianyao_idx = 5 if (c % 6 == 0) else (c % 6 - 1)
    bengua = bagua[xiagua_idx] + bagua[shanggua_idx]
    hugua = bengua[1:-1][:3] + bengua[1:-1][1:]
    biangua = list(bengua)
    biangua[bianyao_idx] = str(1 - int(biangua[bianyao_idx]))
    biangua = "".join(biangua)
    df = pd.DataFrame([[
        guatu[bengua[3:]][0]+guatu[bengua[3:]][2], guatu[hugua[3:]][0]+guatu[hugua[3:]][2], guatu[biangua[3:]][0]+guatu[biangua[3:]][2], 
    ],[
        guatu[bengua[:3]][0]+guatu[bengua[:3]][2], guatu[hugua[:3]][0]+guatu[hugua[:3]][2], guatu[biangua[:3]][0]+guatu[biangua[:3]][2], 
    ]], index=["上卦", "下卦"], columns = [
        guatu[bengua[3:]][1] + guatu[bengua[:3]][1],
        guatu[hugua[3:]][1] + guatu[hugua[:3]][1],
        guatu[biangua[3:]][1] + guatu[biangua[:3]][1],
    ])
    display(df)
    return bengua, hugua, biangua
    
def easy_start_gua():
    """用公历的日、时、分来起卦。"""
    n1, n2, n3 = str(datetime.now())[8:10], str(datetime.now())[11:13], str(datetime.now())[14:16]
    print(n1, n2, n3)
    return three_num_get_gua(int(n1), int(n2), int(n3))
easy_start_gua()

import zhdate
def easy_start_gua_lunar():
    '''用农历的月、日、时辰来起卦。'''
    time_now = datetime.now()
    zh_date_str = str(zhdate.ZhDate.from_datetime(time_now))
    zh_date_str_1 = datetime.strftime(
        datetime(
            *[int(x) for x in re.findall("\d+", zh_date_str)]
        ),
        '%Y-%m-%d'
    )
    zh_hour = (time_now.hour + 1)//2%12+1
    zh_hour_dizhi = "子、丑、寅、卯、辰、巳、午、未、申、酉、戌、亥".split("、")[zh_hour-1]
    
    n1, n2, n3 = zh_date_str_1[5:7], zh_date_str_1[8:10], zh_hour
    print(n1, n2, n3, f"{zh_hour_dizhi}时")
    return three_num_get_gua(int(n1), int(n2), int(n3))
easy_start_gua_lunar()
# Out:
# <>:187: SyntaxWarning: invalid escape sequence '\d'
# <>:187: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/s1/1jpfx0m52rj4k7cgqkh7g3q40000gn/T/ipykernel_4976/2609395125.py:187: SyntaxWarning: invalid escape sequence '\d'
#   *[int(x) for x in re.findall("\d+", zh_date_str)]
# storage dir: /Users/minkexiu/Downloads/GitHub/ML_runCodeFromBook/深入浅出图神经网络
# code dir: /Users/minkexiu/Documents/GitHub/ML_runCodeFromBook/深入浅出图神经网络
# 19 04 45
#      火雷   水山   火火
# 上卦  ☲离火  ☵坎水  ☲离火
# 下卦  ☳震木  ☶艮土  ☲离火
# 08 17 3 寅时
#      地天   雷泽   地泽
# 上卦  ☷坤土  ☳震木  ☷坤土
# 下卦  ☰乾金  ☱兑金  ☱兑金
# ('111000', '110100', '110000')

# %%
import torch

import numpy as np
import torch.nn as nn
import torch.optim as optim
# from net import GraphSage
# from data import CoraData
# from sampling import multihop_sampling

import torch.nn.functional as F
import torch.nn.init as init

from collections import namedtuple

import os
import os.path as osp
import pickle
import itertools
import scipy.sparse as sp
import urllib
from collections import namedtuple

# %%
## 定义数据：

class CoraData(object):
    download_url = "https://github.com/kimiyoung/planetoid/raw/master/data"
    filenames = [
        "ind.cora.{}".format(name) for name in
        ['x', 'tx', 'allx', 'y', 'ty', 'ally', 'graph', 'test.index']
    ]

    def __init__(self, data_root="cora", rebuild=False):
        """Cora数据，包括数据下载，处理，加载等功能
        当数据的缓存文件存在时，将使用缓存文件，否则将下载、进行处理，并缓存到磁盘

        处理之后的数据可以通过属性 .data 获得，它将返回一个数据对象，包括如下几部分：
            * x: 节点的特征，维度为 2708 * 1433，类型为 np.ndarray
            * y: 节点的标签，总共包括7个类别，类型为 np.ndarray
            * adjacency: 邻接矩阵，维度为 2708 * 2708，类型为 scipy.sparse.coo.coo_matrix
            * train_mask: 训练集掩码向量，维度为 2708，当节点属于训练集时，相应位置为True，否则False
            * val_mask: 验证集掩码向量，维度为 2708，当节点属于验证集时，相应位置为True，否则False
            * test_mask: 测试集掩码向量，维度为 2708，当节点属于测试集时，相应位置为True，否则False

        Args:
        -------
            data_root: string, optional
                存放数据的目录，原始数据路径: ../data/cora
                缓存数据路径: {data_root}/ch5_cached.pkl
            rebuild: boolean, optional
                是否需要重新构建数据集，当设为True时，如果存在缓存数据也会重建数据

        """
        print("init...")
        self.data_root = create_originalData_path(data_root)
        save_file = osp.join(self.data_root, "ch5_cached.pkl")
        if osp.exists(save_file) and not rebuild:
            print("Using Cached file: {}".format(save_file))
            self._data = pickle.load(open(save_file, "rb"))
        else:
            if not osp.exists(self.data_root):
                os.makedirs(self.data_root)
            self._data = self.process_data()
            with open(save_file, "wb") as f:
                pickle.dump(self.data, f)
            print("Cached file: {}".format(save_file))
    
    @property
    def data(self):
        """返回Data数据对象，包括x, y, adjacency, train_mask, val_mask, test_mask"""
        return self._data
        
    def process_data(self):
        """
        处理数据，得到节点特征和标签，邻接矩阵，训练集、验证集以及测试集
        引用自：https://github.com/rusty1s/pytorch_geometric
        """
        print("Process data ...")
        _, tx, allx, y, ty, ally, graph, test_index = [
            self.read_data(
                osp.join(self.data_root, name)
            ) for name in self.filenames
        ]
        train_index = np.arange(y.shape[0])
        val_index = np.arange(y.shape[0], y.shape[0] + 500)
        sorted_test_index = sorted(test_index)

        x = np.concatenate((allx, tx), axis=0)
        y = np.concatenate((ally, ty), axis=0).argmax(axis=1)

        x[test_index] = x[sorted_test_index]
        y[test_index] = y[sorted_test_index]
        num_nodes = x.shape[0]

        train_mask = np.zeros(num_nodes, dtype=bool)
        val_mask = np.zeros(num_nodes, dtype=bool)
        test_mask = np.zeros(num_nodes, dtype=bool)
        train_mask[train_index] = True
        val_mask[val_index] = True
        test_mask[test_index] = True
        adjacency = self.build_adjacency(graph)
        print("Node's feature shape: ", x.shape)
        print("Node's label shape: ", y.shape)
        print("Adjacency's shape: ", adjacency.shape)
        print("Number of training nodes: ", train_mask.sum())
        print("Number of validation nodes: ", val_mask.sum())
        print("Number of test nodes: ", test_mask.sum())

        return Data(x=x, y=y, adjacency=adjacency,
                    train_mask=train_mask, val_mask=val_mask, test_mask=test_mask)

    @staticmethod
    def build_adjacency(adj_dict):
        """根据邻接表创建邻接矩阵"""
        edge_index = []
        num_nodes = len(adj_dict)
        for src, dst in adj_dict.items():
            edge_index.extend([src, v] for v in dst)
            edge_index.extend([v, src] for v in dst)
        # 去除重复的边
        edge_index = list(k for k, _ in itertools.groupby(sorted(edge_index)))
        edge_index = np.asarray(edge_index)
        adjacency = sp.coo_matrix((np.ones(len(edge_index)), 
                                   (edge_index[:, 0], edge_index[:, 1])),
                    shape=(num_nodes, num_nodes), dtype="float32")
        return adjacency

    @staticmethod
    def read_data(path):
        """使用不同的方式读取原始数据以进一步处理"""
        name = osp.basename(path)
        if name == "ind.cora.test.index":
            out = np.genfromtxt(path, dtype="int64")
            return out
        else:
            out = pickle.load(open(path, "rb"), encoding="latin1")
            out = out.toarray() if hasattr(out, "toarray") else out
            return out

    @staticmethod
    def normalization(adjacency):
        """计算 L=D^-0.5 * (A+I) * D^-0.5"""
        adjacency += sp.eye(adjacency.shape[0])    # 增加自连接
        degree = np.array(adjacency.sum(1))
        d_hat = sp.diags(np.power(degree, -0.5).flatten())
        return d_hat.dot(adjacency).dot(d_hat).tocoo()

# %%
## 定义网络：

class NeighborAggregator(nn.Module):
    def __init__(self, input_dim, output_dim, 
                 use_bias=False, aggr_method="mean"):
        """聚合节点邻居

        Args:
            input_dim: 输入特征的维度
            output_dim: 输出特征的维度
            use_bias: 是否使用偏置 (default: {False})
            aggr_method: 邻居聚合方式 (default: {mean})
        """
        super(NeighborAggregator, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.use_bias = use_bias
        self.aggr_method = aggr_method
        self.weight = nn.Parameter(torch.Tensor(input_dim, output_dim))
        if self.use_bias:
            self.bias = nn.Parameter(torch.Tensor(self.output_dim))
        self.reset_parameters()
    
    def reset_parameters(self):
        init.kaiming_uniform_(self.weight)
        if self.use_bias:
            init.zeros_(self.bias)

    def forward(self, neighbor_feature):
        if self.aggr_method == "mean":
            aggr_neighbor = neighbor_feature.mean(dim=1)
        elif self.aggr_method == "sum":
            aggr_neighbor = neighbor_feature.sum(dim=1)
        elif self.aggr_method == "max":
            aggr_neighbor = neighbor_feature.max(dim=1)
        else:
            raise ValueError("Unknown aggr type, expected sum, max, or mean, but got {}"
                             .format(self.aggr_method))
        
        neighbor_hidden = torch.matmul(aggr_neighbor, self.weight)
        if self.use_bias:
            neighbor_hidden += self.bias

        return neighbor_hidden

    def extra_repr(self):
        return 'in_features={}, out_features={}, aggr_method={}'.format(
            self.input_dim, self.output_dim, self.aggr_method)
    

class SageGCN(nn.Module):
    def __init__(self, input_dim, hidden_dim,
                 activation=F.relu,
                 aggr_neighbor_method="mean",
                 aggr_hidden_method="sum"):
        """SageGCN层定义

        Args:
            input_dim: 输入特征的维度
            hidden_dim: 隐层特征的维度，
                当aggr_hidden_method=sum, 输出维度为hidden_dim
                当aggr_hidden_method=concat, 输出维度为hidden_dim*2
            activation: 激活函数
            aggr_neighbor_method: 邻居特征聚合方法，["mean", "sum", "max"]
            aggr_hidden_method: 节点特征的更新方法，["sum", "concat"]
        """
        super(SageGCN, self).__init__()
        assert aggr_neighbor_method in ["mean", "sum", "max"]
        assert aggr_hidden_method in ["sum", "concat"]
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.aggr_neighbor_method = aggr_neighbor_method
        self.aggr_hidden_method = aggr_hidden_method
        self.activation = activation
        self.aggregator = NeighborAggregator(input_dim, hidden_dim,
                                             aggr_method=aggr_neighbor_method)
        self.weight = nn.Parameter(torch.Tensor(input_dim, hidden_dim))
        self.reset_parameters()
    
    def reset_parameters(self):
        init.kaiming_uniform_(self.weight)

    def forward(self, src_node_features, neighbor_node_features):
        neighbor_hidden = self.aggregator(neighbor_node_features)
        self_hidden = torch.matmul(src_node_features, self.weight)
        
        if self.aggr_hidden_method == "sum":
            hidden = self_hidden + neighbor_hidden
        elif self.aggr_hidden_method == "concat":
            hidden = torch.cat([self_hidden, neighbor_hidden], dim=1)
        else:
            raise ValueError("Expected sum or concat, got {}"
                             .format(self.aggr_hidden))
        if self.activation:
            return self.activation(hidden)
        else:
            return hidden

    def extra_repr(self):
        output_dim = self.hidden_dim if self.aggr_hidden_method == "sum" else self.hidden_dim * 2
        return 'in_features={}, out_features={}, aggr_hidden_method={}'.format(
            self.input_dim, output_dim, self.aggr_hidden_method)


class GraphSage(nn.Module):
    def __init__(self, input_dim, hidden_dim,
                 num_neighbors_list):
        super(GraphSage, self).__init__()
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.num_neighbors_list = num_neighbors_list
        self.num_layers = len(num_neighbors_list)
        self.gcn = nn.ModuleList()
        self.gcn.append(SageGCN(input_dim, hidden_dim[0]))
        for index in range(0, len(hidden_dim) - 2):
            self.gcn.append(SageGCN(hidden_dim[index], hidden_dim[index+1]))
        self.gcn.append(SageGCN(hidden_dim[-2], hidden_dim[-1], activation=None))

    def forward(self, node_features_list):
        hidden = node_features_list
        for l in range(self.num_layers):
            next_hidden = []
            gcn = self.gcn[l]
            for hop in range(self.num_layers - l):
                src_node_features = hidden[hop]
                src_node_num = len(src_node_features)
                neighbor_node_features = hidden[hop + 1] \
                    .view((src_node_num, self.num_neighbors_list[hop], -1))
                h = gcn(src_node_features, neighbor_node_features)
                next_hidden.append(h)
            hidden = next_hidden
        return hidden[0]

    def extra_repr(self):
        return 'in_features={}, num_neighbors_list={}'.format(
            self.input_dim, self.num_neighbors_list
        )

# %%
## 定义采样的方法：

def sampling(src_nodes, sample_num, neighbor_table):
    """根据源节点采样指定数量的邻居节点，注意使用的是有放回的采样；
    某个节点的邻居节点数量少于采样数量时，采样结果出现重复的节点
    
    Arguments:
        src_nodes {list, ndarray} -- 源节点列表
        sample_num {int} -- 需要采样的节点数
        neighbor_table {dict} -- 节点到其邻居节点的映射表
    
    Returns:
        np.ndarray -- 采样结果构成的列表
    """
    # print("neighbor_table type:", type(neighbor_table))
    results = []
    for sid in src_nodes:
        # 从节点的邻居中进行有放回地进行采样      
        res = np.random.choice(
            np.where(data.adjacency_dict.todense()[113] == 1)[1], 
            size=(sample_num, )
        ) ## np.random.choice(neighbor_table.tocsr()[sid], size=(sample_num, )) 
        ## xmk；这里跟原来的代码有点不一样。原来的代码有问题，查了一下是因为coo类型的矩阵没法是没法index的。
        ## 然后观察了一下，这里代码要实现的意思。所以就自己找了个方法给它修改了，就能跑了。
        results.append(res)
    return np.asarray(results).flatten()


def multihop_sampling(src_nodes, sample_nums, neighbor_table):
    """根据源节点进行多阶采样
    
    Arguments:
        src_nodes {list, np.ndarray} -- 源节点id
        sample_nums {list of int} -- 每一阶需要采样的个数
        neighbor_table {dict} -- 节点到其邻居节点的映射
    
    Returns:
        [list of ndarray] -- 每一阶采样的结果

    xmk: 多重采样的原理其实非常简单。第一步就是起始点，这里比如说是16个。
    首先把这16个节点的list放到 sampling_result 的第一个元素的位置。
    然后看网络有多少层，也就是要有多少跳。
    然后如果是2跳的话，就从 sampling_result 的第一个元素开始，那就是从起始16点开始。然后对每一个节点采样10个，总共组成160个采样结果，这个结果列表放到 sampling_result 的第二个位置。
    然后就是在第二跳的话，就去以160个点开始，每个点再采样10个，于是得到了 sampling_result 的第三个元素，也就是1600个采样点。
    """
    sampling_result = [src_nodes]
    # print(sampling_result)
    for k, hopk_num in enumerate(sample_nums):
        # print(sampling_result[k], type(sampling_result[k]))
        hopk_result = sampling(sampling_result[k], hopk_num, neighbor_table)
        sampling_result.append(hopk_result)
    return sampling_result

# %%
INPUT_DIM = 1433    # 输入维度
# Note: 采样的邻居阶数需要与GCN的层数保持一致
HIDDEN_DIM = [128, 7]   # 隐藏单元节点数
NUM_NEIGHBORS_LIST = [10, 10]   # 每阶采样邻居的节点数
assert len(HIDDEN_DIM) == len(NUM_NEIGHBORS_LIST)
BTACH_SIZE = 16     # 批处理大小
EPOCHS = 20
NUM_BATCH_PER_EPOCH = 20    # 每个epoch循环的批次数
LEARNING_RATE = 0.01    # 学习率
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

Data = namedtuple('Data', ['x', 'y', 'adjacency_dict',
                           'train_mask', 'val_mask', 'test_mask'])

# %%
data = CoraData().data
x = data.x / data.x.sum(1, keepdims=True)  # 归一化数据，使得每一行和为1
# Out:
# init...
# Using Cached file: /Users/minkexiu/Downloads/GitHub/ML_runCodeFromBook/深入浅出图神经网络/originalData/cora/ch5_cached.pkl

# %%
train_index = np.where(data.train_mask)[0]
train_label = data.y
test_index = np.where(data.test_mask)[0]
model = GraphSage(input_dim=INPUT_DIM, hidden_dim=HIDDEN_DIM,
                  num_neighbors_list=NUM_NEIGHBORS_LIST).to(DEVICE)
print(model)
criterion = nn.CrossEntropyLoss().to(DEVICE)
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=5e-4)
# Out:
# GraphSage(
#   in_features=1433, num_neighbors_list=[10, 10]
#   (gcn): ModuleList(
#     (0): SageGCN(
#       in_features=1433, out_features=128, aggr_hidden_method=sum
#       (aggregator): NeighborAggregator(in_features=1433, out_features=128, aggr_method=mean)
#     )
#     (1): SageGCN(
#       in_features=128, out_features=7, aggr_hidden_method=sum
#       (aggregator): NeighborAggregator(in_features=128, out_features=7, aggr_method=mean)
#     )
#   )
# )

# %%
def train():
    model.train()
    for e in range(EPOCHS):
        for batch in range(NUM_BATCH_PER_EPOCH):
            batch_src_index = np.random.choice(train_index, size=(BTACH_SIZE,))
            batch_src_label = torch.from_numpy(train_label[batch_src_index]).long().to(DEVICE)
            batch_sampling_result = multihop_sampling(batch_src_index, NUM_NEIGHBORS_LIST, data.adjacency_dict)
            ## xmk：batch_sampling_result 是一个列表的列表，采样2跳，那就有3个元素在里面。每一个元素都是列表，长度分别为16，160，1600.
            ## 每一个列表中的节点都可以是采样点。
            batch_sampling_x = [torch.from_numpy(x[idx]).float().to(DEVICE) for idx in batch_sampling_result]
            ## xmk: 我看懂了它逐层操作的逻辑。换句话说就是，我看懂了GraphSage.forward方法的底细。只能说我懂作者的意图，但是作者的实现方式似乎能够有所优化。作者的操作，实现上没啥问题，
            ## 但我直观的感觉就是，它可优化的余地蛮大。
            batch_train_logits = model(batch_sampling_x)
            ## xmk：其实原始的代码没有对concat做支持，concat完之后最后输出的logit的维度变成原来的两倍，但是logit并没有被以某种形式变回原来的维度。
            loss = criterion(batch_train_logits, batch_src_label)
            optimizer.zero_grad()
            loss.backward()  # 反向传播计算参数的梯度
            optimizer.step()  # 使用优化方法进行梯度更新
            print("Epoch {:03d} Batch {:03d} Loss: {:.4f}".format(e, batch, loss.item()))
        test()


def test():
    model.eval()
    with torch.no_grad():
        test_sampling_result = multihop_sampling(test_index, NUM_NEIGHBORS_LIST, data.adjacency_dict)
        test_x = [torch.from_numpy(x[idx]).float().to(DEVICE) for idx in test_sampling_result]
        test_logits = model(test_x)
        test_label = torch.from_numpy(data.y[test_index]).long().to(DEVICE)
        predict_y = test_logits.max(1)[1]
        accuarcy = torch.eq(predict_y, test_label).float().mean().item()
        print("Test Accuracy: ", accuarcy)

# %%
with TimerContext():
    train()
# Out:
# start time: 2024-09-19 04:45:45.813334
# Epoch 000 Batch 000 Loss: 1.9274
# Epoch 000 Batch 001 Loss: 1.8746
# Epoch 000 Batch 002 Loss: 1.8838
# Epoch 000 Batch 003 Loss: 1.9757
# Epoch 000 Batch 004 Loss: 2.0479
# Epoch 000 Batch 005 Loss: 1.6532
# Epoch 000 Batch 006 Loss: 1.8086
# Epoch 000 Batch 007 Loss: 1.8862
# Epoch 000 Batch 008 Loss: 1.5339
# Epoch 000 Batch 009 Loss: 1.6414
# Epoch 000 Batch 010 Loss: 1.6935
# Epoch 000 Batch 011 Loss: 1.5198
# Epoch 000 Batch 012 Loss: 1.6080
# Epoch 000 Batch 013 Loss: 1.2261
# Epoch 000 Batch 014 Loss: 1.3545
# Epoch 000 Batch 015 Loss: 1.3435
# Epoch 000 Batch 016 Loss: 1.4868
# Epoch 000 Batch 017 Loss: 1.1374
# Epoch 000 Batch 018 Loss: 1.2231
# Epoch 000 Batch 019 Loss: 1.2125
# Test Accuracy:  0.414000004529953
# Epoch 001 Batch 000 Loss: 1.0978
# Epoch 001 Batch 001 Loss: 1.0173
# Epoch 001 Batch 002 Loss: 0.8563
# Epoch 001 Batch 003 Loss: 0.8394
# Epoch 001 Batch 004 Loss: 0.7921
# Epoch 001 Batch 005 Loss: 0.9846
# Epoch 001 Batch 006 Loss: 0.7736
# Epoch 001 Batch 007 Loss: 0.7993
# Epoch 001 Batch 008 Loss: 0.6552
# Epoch 001 Batch 009 Loss: 0.6822
# Epoch 001 Batch 010 Loss: 0.7456
# Epoch 001 Batch 011 Loss: 0.6217
# Epoch 001 Batch 012 Loss: 0.4722
# Epoch 001 Batch 013 Loss: 0.5781
# Epoch 001 Batch 014 Loss: 0.4332
# Epoch 001 Batch 015 Loss: 0.4916
# Epoch 001 Batch 016 Loss: 0.3293
# Epoch 001 Batch 017 Loss: 0.3283
# Epoch 001 Batch 018 Loss: 0.3134
# Epoch 001 Batch 019 Loss: 0.2589
# Test Accuracy:  0.4860000014305115
# Epoch 002 Batch 000 Loss: 0.3270
# Epoch 002 Batch 001 Loss: 0.2935
# Epoch 002 Batch 002 Loss: 0.3833
# Epoch 002 Batch 003 Loss: 0.2066
# Epoch 002 Batch 004 Loss: 0.3263
# Epoch 002 Batch 005 Loss: 0.2678
# Epoch 002 Batch 006 Loss: 0.1809
# Epoch 002 Batch 007 Loss: 0.3080
# Epoch 002 Batch 008 Loss: 0.1845
# Epoch 002 Batch 009 Loss: 0.1973
# Epoch 002 Batch 010 Loss: 0.1381
# Epoch 002 Batch 011 Loss: 0.1096
# Epoch 002 Batch 012 Loss: 0.1257
# Epoch 002 Batch 013 Loss: 0.1195
# Epoch 002 Batch 014 Loss: 0.1283
# Epoch 002 Batch 015 Loss: 0.1456
# Epoch 002 Batch 016 Loss: 0.1699
# Epoch 002 Batch 017 Loss: 0.1133
# Epoch 002 Batch 018 Loss: 0.2476
# Epoch 002 Batch 019 Loss: 0.0739
# Test Accuracy:  0.5740000009536743
# Epoch 003 Batch 000 Loss: 0.0899
# Epoch 003 Batch 001 Loss: 0.0563
# Epoch 003 Batch 002 Loss: 0.0632
# Epoch 003 Batch 003 Loss: 0.1031
# Epoch 003 Batch 004 Loss: 0.0800
# Epoch 003 Batch 005 Loss: 0.1847
# Epoch 003 Batch 006 Loss: 0.1041
# Epoch 003 Batch 007 Loss: 0.0789
# Epoch 003 Batch 008 Loss: 0.0976
# Epoch 003 Batch 009 Loss: 0.1565
# Epoch 003 Batch 010 Loss: 0.0706
# Epoch 003 Batch 011 Loss: 0.0833
# Epoch 003 Batch 012 Loss: 0.1221
# Epoch 003 Batch 013 Loss: 0.0802
# Epoch 003 Batch 014 Loss: 0.0788
# Epoch 003 Batch 015 Loss: 0.1039
# Epoch 003 Batch 016 Loss: 0.0796
# Epoch 003 Batch 017 Loss: 0.0975
# Epoch 003 Batch 018 Loss: 0.0893
# Epoch 003 Batch 019 Loss: 0.0611
# Test Accuracy:  0.5820000171661377
# Epoch 004 Batch 000 Loss: 0.0741
# Epoch 004 Batch 001 Loss: 0.0860
# Epoch 004 Batch 002 Loss: 0.0917
# Epoch 004 Batch 003 Loss: 0.0929
# Epoch 004 Batch 004 Loss: 0.0629
# Epoch 004 Batch 005 Loss: 0.0586
# Epoch 004 Batch 006 Loss: 0.0759
# Epoch 004 Batch 007 Loss: 0.0733
# Epoch 004 Batch 008 Loss: 0.0948
# Epoch 004 Batch 009 Loss: 0.0584
# Epoch 004 Batch 010 Loss: 0.0748
# Epoch 004 Batch 011 Loss: 0.0695
# Epoch 004 Batch 012 Loss: 0.0697
# Epoch 004 Batch 013 Loss: 0.0834
# Epoch 004 Batch 014 Loss: 0.0751
# Epoch 004 Batch 015 Loss: 0.0738
# Epoch 004 Batch 016 Loss: 0.0709
# Epoch 004 Batch 017 Loss: 0.0913
# Epoch 004 Batch 018 Loss: 0.0757
# Epoch 004 Batch 019 Loss: 0.0711
# Test Accuracy:  0.5659999847412109
# Epoch 005 Batch 000 Loss: 0.0709
# Epoch 005 Batch 001 Loss: 0.0801
# Epoch 005 Batch 002 Loss: 0.0729
# Epoch 005 Batch 003 Loss: 0.0789
# Epoch 005 Batch 004 Loss: 0.0716
# Epoch 005 Batch 005 Loss: 0.0990
# Epoch 005 Batch 006 Loss: 0.0774
# Epoch 005 Batch 007 Loss: 0.0756
# Epoch 005 Batch 008 Loss: 0.0627
# Epoch 005 Batch 009 Loss: 0.0705
# Epoch 005 Batch 010 Loss: 0.0868
# Epoch 005 Batch 011 Loss: 0.0856
# Epoch 005 Batch 012 Loss: 0.0860
# Epoch 005 Batch 013 Loss: 0.0877
# Epoch 005 Batch 014 Loss: 0.0735
# Epoch 005 Batch 015 Loss: 0.0659
# Epoch 005 Batch 016 Loss: 0.1439
# Epoch 005 Batch 017 Loss: 0.0748
# Epoch 005 Batch 018 Loss: 0.0821
# Epoch 005 Batch 019 Loss: 0.0584
# Test Accuracy:  0.578000009059906
# Epoch 006 Batch 000 Loss: 0.0998
# Epoch 006 Batch 001 Loss: 0.0697
# Epoch 006 Batch 002 Loss: 0.0536
# Epoch 006 Batch 003 Loss: 0.0597
# Epoch 006 Batch 004 Loss: 0.0570
# Epoch 006 Batch 005 Loss: 0.0669
# Epoch 006 Batch 006 Loss: 0.0784
# Epoch 006 Batch 007 Loss: 0.0932
# Epoch 006 Batch 008 Loss: 0.0749
# Epoch 006 Batch 009 Loss: 0.0874
# Epoch 006 Batch 010 Loss: 0.1114
# Epoch 006 Batch 011 Loss: 0.0737
# Epoch 006 Batch 012 Loss: 0.0745
# Epoch 006 Batch 013 Loss: 0.0755
# Epoch 006 Batch 014 Loss: 0.0629
# Epoch 006 Batch 015 Loss: 0.0594
# Epoch 006 Batch 016 Loss: 0.0684
# Epoch 006 Batch 017 Loss: 0.0773
# Epoch 006 Batch 018 Loss: 0.0921
# Epoch 006 Batch 019 Loss: 0.0770
# Test Accuracy:  0.5950000286102295
# Epoch 007 Batch 000 Loss: 0.0943
# Epoch 007 Batch 001 Loss: 0.0672
# Epoch 007 Batch 002 Loss: 0.0540
# Epoch 007 Batch 003 Loss: 0.1008
# Epoch 007 Batch 004 Loss: 0.0616
# Epoch 007 Batch 005 Loss: 0.0748
# Epoch 007 Batch 006 Loss: 0.0781
# Epoch 007 Batch 007 Loss: 0.0661
# Epoch 007 Batch 008 Loss: 0.0653
# Epoch 007 Batch 009 Loss: 0.0758
# Epoch 007 Batch 010 Loss: 0.0449
# Epoch 007 Batch 011 Loss: 0.0691
# Epoch 007 Batch 012 Loss: 0.1132
# Epoch 007 Batch 013 Loss: 0.0767
# Epoch 007 Batch 014 Loss: 0.0712
# Epoch 007 Batch 015 Loss: 0.0726
# Epoch 007 Batch 016 Loss: 0.0780
# Epoch 007 Batch 017 Loss: 0.0880
# Epoch 007 Batch 018 Loss: 0.0709
# Epoch 007 Batch 019 Loss: 0.0703
# Test Accuracy:  0.5659999847412109
# Epoch 008 Batch 000 Loss: 0.0476
# Epoch 008 Batch 001 Loss: 0.0755
# Epoch 008 Batch 002 Loss: 0.0668
# Epoch 008 Batch 003 Loss: 0.0675
# Epoch 008 Batch 004 Loss: 0.0886
# Epoch 008 Batch 005 Loss: 0.0532
# Epoch 008 Batch 006 Loss: 0.0851
# Epoch 008 Batch 007 Loss: 0.0640
# Epoch 008 Batch 008 Loss: 0.0683
# Epoch 008 Batch 009 Loss: 0.0618
# Epoch 008 Batch 010 Loss: 0.0570
# Epoch 008 Batch 011 Loss: 0.0768
# Epoch 008 Batch 012 Loss: 0.0662
# Epoch 008 Batch 013 Loss: 0.0632
# Epoch 008 Batch 014 Loss: 0.0846
# Epoch 008 Batch 015 Loss: 0.0773
# Epoch 008 Batch 016 Loss: 0.0659
# Epoch 008 Batch 017 Loss: 0.0840
# Epoch 008 Batch 018 Loss: 0.1197
# Epoch 008 Batch 019 Loss: 0.0633
# Test Accuracy:  0.5759999752044678
# Epoch 009 Batch 000 Loss: 0.1089
# Epoch 009 Batch 001 Loss: 0.0822
# Epoch 009 Batch 002 Loss: 0.0778
# Epoch 009 Batch 003 Loss: 0.0620
# Epoch 009 Batch 004 Loss: 0.0550
# Epoch 009 Batch 005 Loss: 0.0613
# Epoch 009 Batch 006 Loss: 0.0769
# Epoch 009 Batch 007 Loss: 0.0794
# Epoch 009 Batch 008 Loss: 0.0658
# Epoch 009 Batch 009 Loss: 0.0696
# Epoch 009 Batch 010 Loss: 0.0689
# Epoch 009 Batch 011 Loss: 0.0863
# Epoch 009 Batch 012 Loss: 0.0707
# Epoch 009 Batch 013 Loss: 0.0835
# Epoch 009 Batch 014 Loss: 0.0755
# Epoch 009 Batch 015 Loss: 0.0658
# Epoch 009 Batch 016 Loss: 0.0631
# Epoch 009 Batch 017 Loss: 0.0579
# Epoch 009 Batch 018 Loss: 0.0809
# Epoch 009 Batch 019 Loss: 0.0756
# Test Accuracy:  0.6069999933242798
# Epoch 010 Batch 000 Loss: 0.0816
# Epoch 010 Batch 001 Loss: 0.0846
# Epoch 010 Batch 002 Loss: 0.0787
# Epoch 010 Batch 003 Loss: 0.0994
# Epoch 010 Batch 004 Loss: 0.0885
# Epoch 010 Batch 005 Loss: 0.0717
# Epoch 010 Batch 006 Loss: 0.0467
# Epoch 010 Batch 007 Loss: 0.0507
# Epoch 010 Batch 008 Loss: 0.0635
# Epoch 010 Batch 009 Loss: 0.0514
# Epoch 010 Batch 010 Loss: 0.0885
# Epoch 010 Batch 011 Loss: 0.0540
# Epoch 010 Batch 012 Loss: 0.0797
# Epoch 010 Batch 013 Loss: 0.0565
# Epoch 010 Batch 014 Loss: 0.0863
# Epoch 010 Batch 015 Loss: 0.0507
# Epoch 010 Batch 016 Loss: 0.0543
# Epoch 010 Batch 017 Loss: 0.0818
# Epoch 010 Batch 018 Loss: 0.0646
# Epoch 010 Batch 019 Loss: 0.0647
# Test Accuracy:  0.5590000152587891
# Epoch 011 Batch 000 Loss: 0.0798
# Epoch 011 Batch 001 Loss: 0.0959
# Epoch 011 Batch 002 Loss: 0.0613
# Epoch 011 Batch 003 Loss: 0.0736
# Epoch 011 Batch 004 Loss: 0.0570
# Epoch 011 Batch 005 Loss: 0.0588
# Epoch 011 Batch 006 Loss: 0.0598
# Epoch 011 Batch 007 Loss: 0.0647
# Epoch 011 Batch 008 Loss: 0.1060
# Epoch 011 Batch 009 Loss: 0.0877
# Epoch 011 Batch 010 Loss: 0.0486
# Epoch 011 Batch 011 Loss: 0.0523
# Epoch 011 Batch 012 Loss: 0.0655
# Epoch 011 Batch 013 Loss: 0.0589
# Epoch 011 Batch 014 Loss: 0.0564
# Epoch 011 Batch 015 Loss: 0.0647
# Epoch 011 Batch 016 Loss: 0.0661
# Epoch 011 Batch 017 Loss: 0.0900
# Epoch 011 Batch 018 Loss: 0.0903
# Epoch 011 Batch 019 Loss: 0.0782
# Test Accuracy:  0.5759999752044678
# Epoch 012 Batch 000 Loss: 0.0650
# Epoch 012 Batch 001 Loss: 0.0686
# Epoch 012 Batch 002 Loss: 0.0525
# Epoch 012 Batch 003 Loss: 0.0759
# Epoch 012 Batch 004 Loss: 0.0537
# Epoch 012 Batch 005 Loss: 0.0635
# Epoch 012 Batch 006 Loss: 0.0574
# Epoch 012 Batch 007 Loss: 0.0629
# Epoch 012 Batch 008 Loss: 0.0455
# Epoch 012 Batch 009 Loss: 0.0591
# Epoch 012 Batch 010 Loss: 0.0482
# Epoch 012 Batch 011 Loss: 0.0508
# Epoch 012 Batch 012 Loss: 0.0476
# Epoch 012 Batch 013 Loss: 0.0489
# Epoch 012 Batch 014 Loss: 0.0454
# Epoch 012 Batch 015 Loss: 0.0404
# Epoch 012 Batch 016 Loss: 0.0645
# Epoch 012 Batch 017 Loss: 0.0828
# Epoch 012 Batch 018 Loss: 0.0656
# Epoch 012 Batch 019 Loss: 0.0452
# Test Accuracy:  0.5770000219345093
# Epoch 013 Batch 000 Loss: 0.0599
# Epoch 013 Batch 001 Loss: 0.0860
# Epoch 013 Batch 002 Loss: 0.0500
# Epoch 013 Batch 003 Loss: 0.0670
# Epoch 013 Batch 004 Loss: 0.0832
# Epoch 013 Batch 005 Loss: 0.0688
# Epoch 013 Batch 006 Loss: 0.0662
# Epoch 013 Batch 007 Loss: 0.0787
# Epoch 013 Batch 008 Loss: 0.0567
# Epoch 013 Batch 009 Loss: 0.0685
# Epoch 013 Batch 010 Loss: 0.0487
# Epoch 013 Batch 011 Loss: 0.0508
# Epoch 013 Batch 012 Loss: 0.0529
# Epoch 013 Batch 013 Loss: 0.0874
# Epoch 013 Batch 014 Loss: 0.0745
# Epoch 013 Batch 015 Loss: 0.0794
# Epoch 013 Batch 016 Loss: 0.0810
# Epoch 013 Batch 017 Loss: 0.0713
# Epoch 013 Batch 018 Loss: 0.0648
# Epoch 013 Batch 019 Loss: 0.1030
# Test Accuracy:  0.5839999914169312
# Epoch 014 Batch 000 Loss: 0.0541
# Epoch 014 Batch 001 Loss: 0.0700
# Epoch 014 Batch 002 Loss: 0.0732
# Epoch 014 Batch 003 Loss: 0.0759
# Epoch 014 Batch 004 Loss: 0.0559
# Epoch 014 Batch 005 Loss: 0.0495
# Epoch 014 Batch 006 Loss: 0.0604
# Epoch 014 Batch 007 Loss: 0.0989
# Epoch 014 Batch 008 Loss: 0.0770
# Epoch 014 Batch 009 Loss: 0.0607
# Epoch 014 Batch 010 Loss: 0.0609
# Epoch 014 Batch 011 Loss: 0.0563
# Epoch 014 Batch 012 Loss: 0.0642
# Epoch 014 Batch 013 Loss: 0.0656
# Epoch 014 Batch 014 Loss: 0.0661
# Epoch 014 Batch 015 Loss: 0.0801
# Epoch 014 Batch 016 Loss: 0.0751
# Epoch 014 Batch 017 Loss: 0.0608
# Epoch 014 Batch 018 Loss: 0.0760
# Epoch 014 Batch 019 Loss: 0.0548
# Test Accuracy:  0.625
# Epoch 015 Batch 000 Loss: 0.0736
# Epoch 015 Batch 001 Loss: 0.0643
# Epoch 015 Batch 002 Loss: 0.0925
# Epoch 015 Batch 003 Loss: 0.0604
# Epoch 015 Batch 004 Loss: 0.0474
# Epoch 015 Batch 005 Loss: 0.0761
# Epoch 015 Batch 006 Loss: 0.0806
# Epoch 015 Batch 007 Loss: 0.0657
# Epoch 015 Batch 008 Loss: 0.0412
# Epoch 015 Batch 009 Loss: 0.0548
# Epoch 015 Batch 010 Loss: 0.0745
# Epoch 015 Batch 011 Loss: 0.0820
# Epoch 015 Batch 012 Loss: 0.0476
# Epoch 015 Batch 013 Loss: 0.0555
# Epoch 015 Batch 014 Loss: 0.0716
# Epoch 015 Batch 015 Loss: 0.0744
# Epoch 015 Batch 016 Loss: 0.0477
# Epoch 015 Batch 017 Loss: 0.0652
# Epoch 015 Batch 018 Loss: 0.0845
# Epoch 015 Batch 019 Loss: 0.0612
# Test Accuracy:  0.6119999885559082
# Epoch 016 Batch 000 Loss: 0.0365
# Epoch 016 Batch 001 Loss: 0.0492
# Epoch 016 Batch 002 Loss: 0.0661
# Epoch 016 Batch 003 Loss: 0.0481
# Epoch 016 Batch 004 Loss: 0.0398
# Epoch 016 Batch 005 Loss: 0.0628
# Epoch 016 Batch 006 Loss: 0.0489
# Epoch 016 Batch 007 Loss: 0.1098
# Epoch 016 Batch 008 Loss: 0.0687
# Epoch 016 Batch 009 Loss: 0.0548
# Epoch 016 Batch 010 Loss: 0.0698
# Epoch 016 Batch 011 Loss: 0.0662
# Epoch 016 Batch 012 Loss: 0.0625
# Epoch 016 Batch 013 Loss: 0.0558
# Epoch 016 Batch 014 Loss: 0.0972
# Epoch 016 Batch 015 Loss: 0.0689
# Epoch 016 Batch 016 Loss: 0.0706
# Epoch 016 Batch 017 Loss: 0.0764
# Epoch 016 Batch 018 Loss: 0.0491
# Epoch 016 Batch 019 Loss: 0.0497
# Test Accuracy:  0.5709999799728394
# Epoch 017 Batch 000 Loss: 0.0764
# Epoch 017 Batch 001 Loss: 0.0606
# Epoch 017 Batch 002 Loss: 0.0545
# Epoch 017 Batch 003 Loss: 0.0888
# Epoch 017 Batch 004 Loss: 0.0671
# Epoch 017 Batch 005 Loss: 0.0619
# Epoch 017 Batch 006 Loss: 0.0567
# Epoch 017 Batch 007 Loss: 0.0910
# Epoch 017 Batch 008 Loss: 0.0487
# Epoch 017 Batch 009 Loss: 0.0394
# Epoch 017 Batch 010 Loss: 0.0592
# Epoch 017 Batch 011 Loss: 0.0749
# Epoch 017 Batch 012 Loss: 0.0583
# Epoch 017 Batch 013 Loss: 0.0558
# Epoch 017 Batch 014 Loss: 0.0581
# Epoch 017 Batch 015 Loss: 0.0625
# Epoch 017 Batch 016 Loss: 0.1011
# Epoch 017 Batch 017 Loss: 0.0701
# Epoch 017 Batch 018 Loss: 0.0628
# Epoch 017 Batch 019 Loss: 0.0813
# Test Accuracy:  0.5889999866485596
# Epoch 018 Batch 000 Loss: 0.0422
# Epoch 018 Batch 001 Loss: 0.0723
# Epoch 018 Batch 002 Loss: 0.0594
# Epoch 018 Batch 003 Loss: 0.1070
# Epoch 018 Batch 004 Loss: 0.0638
# Epoch 018 Batch 005 Loss: 0.0566
# Epoch 018 Batch 006 Loss: 0.0563
# Epoch 018 Batch 007 Loss: 0.0756
# Epoch 018 Batch 008 Loss: 0.0658
# Epoch 018 Batch 009 Loss: 0.0569
# Epoch 018 Batch 010 Loss: 0.0765
# Epoch 018 Batch 011 Loss: 0.0505
# Epoch 018 Batch 012 Loss: 0.0596
# Epoch 018 Batch 013 Loss: 0.0856
# Epoch 018 Batch 014 Loss: 0.0561
# Epoch 018 Batch 015 Loss: 0.0798
# Epoch 018 Batch 016 Loss: 0.0538
# Epoch 018 Batch 017 Loss: 0.0812
# Epoch 018 Batch 018 Loss: 0.0561
# Epoch 018 Batch 019 Loss: 0.0686
# Test Accuracy:  0.6050000190734863
# Epoch 019 Batch 000 Loss: 0.1006
# Epoch 019 Batch 001 Loss: 0.0951
# Epoch 019 Batch 002 Loss: 0.0647
# Epoch 019 Batch 003 Loss: 0.0591
# Epoch 019 Batch 004 Loss: 0.0610
# Epoch 019 Batch 005 Loss: 0.0487
# Epoch 019 Batch 006 Loss: 0.0463
# Epoch 019 Batch 007 Loss: 0.0951
# Epoch 019 Batch 008 Loss: 0.0612
# Epoch 019 Batch 009 Loss: 0.0616
# Epoch 019 Batch 010 Loss: 0.0418
# Epoch 019 Batch 011 Loss: 0.0389
# Epoch 019 Batch 012 Loss: 0.0646
# Epoch 019 Batch 013 Loss: 0.0372
# Epoch 019 Batch 014 Loss: 0.0772
# Epoch 019 Batch 015 Loss: 0.0611
# Epoch 019 Batch 016 Loss: 0.0412
# Epoch 019 Batch 017 Loss: 0.0498
# Epoch 019 Batch 018 Loss: 0.0505
# Epoch 019 Batch 019 Loss: 0.0754
# Test Accuracy:  0.5789999961853027
# start time: 2024-09-19 04:45:45.813334
# end time 2024-09-19 04:46:51.943722
