# %%
# !python classify_convnext_tiny.py
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Epoch 0: train_loss=3.0008 train_acc=0.1630
# Epoch 0: val_acc=0.0000
# Epoch 1: train_loss=2.5142 train_acc=0.2000
# Epoch 1: val_acc=0.0000
# Epoch 2: train_loss=2.4263 train_acc=0.1778
# Epoch 2: val_acc=0.0000
# Epoch 3: train_loss=2.4523 train_acc=0.1704
# Epoch 3: val_acc=0.0000
# Epoch 4: train_loss=2.4046 train_acc=0.1778
# Epoch 4: val_acc=0.0000
# Epoch 5: train_loss=2.3868 train_acc=0.1704
# Epoch 5: val_acc=0.0000
# Epoch 6: train_loss=2.4205 train_acc=0.1852
# Epoch 6: val_acc=0.0000
# Epoch 7: train_loss=2.3876 train_acc=0.1778
# Epoch 7: val_acc=0.0000
# Epoch 8: train_loss=2.3723 train_acc=0.1704
# Epoch 8: val_acc=0.0000
# ...

# %%
# !ls /mnt/d/forCoding_data/ML_runCodeFromBook/HuggingFace扩散模型/originalData/Q版大明衣冠图志/"20 婚礼冠服"
# Out:
# '20080403_318b8d7e4120a23879ce2PI9s7UifrQ5[1].jpg'
# '20080403_de164416aeaca7ba662eoDdGgdSnIID5[1].jpg'
#  21238987_977275.jpg
#  21239004_977275.jpg
#  21239014_977275.jpg
#  21239027_977275.jpg
#  21239056_977275.jpg
#  21239075_977275.jpg
#  21239088_977275.jpg
#  96e654a77bb66a9bd0435832.jpg

# %%
# !pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 16.7 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [scikit-learn] [scikit-learn]
# ...
