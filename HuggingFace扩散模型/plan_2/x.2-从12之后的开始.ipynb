# %%
## 增加了负载均衡。
# !python 13_震-基于12_MoE负载均衡.py --n_epochs 315
## 感觉生成的图还是挺抽象的，没有12好。
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 100%|███████████████████████████████████████████| 43/43 [00:07<00:00,  5.83it/s]
# Finished epoch 0. Average of the last 100 loss values: 0.332297
# 100%|███████████████████████████████████████████| 43/43 [00:08<00:00,  5.11it/s]
# Finished epoch 1. Average of the last 100 loss values: 0.527590
# 100%|███████████████████████████████████████████| 43/43 [00:08<00:00,  5.07it/s]
# Finished epoch 2. Average of the last 100 loss values: 0.454205
# 100%|███████████████████████████████████████████| 43/43 [00:08<00:00,  5.06it/s]
# Finished epoch 3. Average of the last 100 loss values: 0.373792
# ...

# %%
# !python 15_渐-基于10_cp2-swin.py --n_epochs 315
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 100%|███████████████████████████████████████████| 43/43 [00:05<00:00,  8.55it/s]
# Finished epoch 0. Average of the last 100 loss values: 0.312825
# 100%|███████████████████████████████████████████| 43/43 [00:04<00:00,  9.49it/s]
# Finished epoch 1. Average of the last 100 loss values: 0.477986
# 100%|███████████████████████████████████████████| 43/43 [00:04<00:00,  9.44it/s]
# Finished epoch 2. Average of the last 100 loss values: 0.419059
# 100%|███████████████████████████████████████████| 43/43 [00:04<00:00,  9.58it/s]
# Finished epoch 3. Average of the last 100 loss values: 0.350496
# ...

# %%
# !python compare_models_generate.py
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 已检测到现有模型，加载并续训: /mnt/d/forCoding_code/ML_runCodeFromBook/HuggingFace扩散模型/plan_2/12_鼎-基于10_新尝试_model.pth
# 模型已保存到: /mnt/d/forCoding_code/ML_runCodeFromBook/HuggingFace扩散模型/plan_2/12_鼎-基于10_新尝试_model.pth
# 已检测到现有模型，加载并续训: /mnt/d/forCoding_code/ML_runCodeFromBook/HuggingFace扩散模型/plan_2/10_井_cp2-基于10_生成大图_model.pth
# 模型已保存到: /mnt/d/forCoding_code/ML_runCodeFromBook/HuggingFace扩散模型/plan_2/10_井_cp2-基于10_生成大图_model.pth
# 已检测到现有模型，加载并续训: /mnt/d/forCoding_code/ML_runCodeFromBook/HuggingFace扩散模型/plan_2/13_震-基于12_MoE负载均衡_model.pth
# 模型已保存到: /mnt/d/forCoding_code/ML_runCodeFromBook/HuggingFace扩散模型/plan_2/13_震-基于12_MoE负载均衡_model.pth
